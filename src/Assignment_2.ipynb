# %%
import pandas as pd
from datetime import datetime

# %%
data = pd.read_csv('/content/train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# ...

# %% [markdown]
# # a)Handling missing values

# %%
missing_values = data.isnull().sum()

# %%
print("Missing values in each column:")
# Out:
# Missing values in each column:

# %%
print(missing_values)
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# ...

# %% [markdown]
# #Replace with the Mean,mode,Median or drop them.

# %%
data['Mileage'] = data['Mileage'].str.replace(r'\D', '', regex=True)

# %%
data['Mileage'] = pd.to_numeric(data['Mileage'], errors='coerce')

# %%
data['Mileage'].fillna(data['Mileage'].mean(), inplace=True)

# %%
data['Engine'] = data['Engine'].str.replace(r'\D', '', regex=True)

# %%
data['Engine'] = pd.to_numeric(data['Engine'], errors='coerce')

# %%
data['Engine'].fillna(data['Engine'].mean(), inplace=True)

# %%
data['Power'] = data['Power'].str.replace(r'\D', '', regex=True)

# %%
data['Power'] = pd.to_numeric(data['Power'], errors='coerce')

# %%
data['Power'].fillna(data['Power'].mean(), inplace=True)

# %%
data['Seats'].fillna(data['Seats'].mean(), inplace=True)

# %%
data.drop(columns=['New_Price'], inplace=True)

# %%
updated_missing_values = data.isnull().sum()

# %%
print("\nUpdated missing values in each column:")
# Out:
# Updated missing values in each column:

# %%
print(updated_missing_values)
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# mileage, power, seats, engine
# i)The columns "Mileage," "Power," "Seats," and "Engine" are fundamental attributes of a used car. These features are often essential for predicting a car's price, condition, and performance.
# ii)Dropping these columns would reduce the dimensionality of your dataset
# *These columns can also enhance the interpretability of your analysis
# iii)New price
# *High Missing Values
# *Even if you were to impute missing values, the "New Price" data might not be of high quality or up-to-date, potentially introducing noise or inaccuracies into our analysis.

# %% [markdown]
# b) Removing Units , No need to clear already while doing mean, mode, median for the null values Units has been removed .PFB results

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First   1967.0  1582.0
# 1              46000    Petrol       Manual      First     13.0  1199.0
# 2              87000    Diesel       Manual      First   2077.0  1248.0
# 3              40670    Diesel    Automatic     Second    152.0  1968.0
# 4              86999    Diesel       Manual      First   2308.0  1461.0
#
#     Power  Seats  Price
# 0  1262.0    5.0  12.50
# 1   887.0    5.0   4.50
# 2  8876.0    7.0   6.00
# 3  1408.0    5.0  17.74
# ...

# %% [markdown]
# C) Change the categorical variable

# %%
data = pd.get_dummies(data, columns=['Fuel_Type', 'Transmission'], drop_first=True)

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First   1967.0  1582.0  1262.0    5.0  12.50
# 1              46000      First     13.0  1199.0   887.0    5.0   4.50
# 2              87000      First   2077.0  1248.0  8876.0    7.0   6.00
# 3              40670     Second    152.0  1968.0  1408.0    5.0  17.74
# 4              86999      First   2308.0  1461.0   631.0    5.0   3.50
#
#    Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual
# 0                   0                 0                    1
# ...

# %% [markdown]
# D) Create one more New Feature

# %%
current_year = datetime.now().year

# %%
data['Car_Age'] = current_year - data['Year']

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First   1967.0  1582.0  1262.0    5.0  12.50
# 1              46000      First     13.0  1199.0   887.0    5.0   4.50
# 2              87000      First   2077.0  1248.0  8876.0    7.0   6.00
# 3              40670     Second    152.0  1968.0  1408.0    5.0  17.74
# 4              86999      First   2308.0  1461.0   631.0    5.0   3.50
#
#    Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual  Car_Age
# 0                   0                 0                    1        8
# ...

# %% [markdown]
# Store the processed dataset

# %%
data.to_csv('cleandataset_train.csv', index = False)
